# %% [markdown]
# ---
# # *`Marketing metrics`*
# ---
#
# <div class="alert alert-block alert-success">
# <ul><br>
#
# ## `Coдержание` :<br>
#
# [**Описание исследуемого набора данных**](#Описание-исследуемого-набора-данных)
#
#
#  [**Задачи**](#Задачи:) :
#
# 1. [**Задание**](#Задание-№1)
#
#     1.1 [*Решение*](#1.1-Решение)
#
#     1.2 [*Вывод*](#1.2-Вывод)
#
#
# 2. [**Задание**](#Задание-№2)
#
#     2.1 [*Решение*](#2.1-Решение)
#
#     2.2 [*Вывод*](#2.2-Вывод)
#
#
# 3. [**Задание**](#Задание-№3)
#
#     3.1 [*Решение*](#3.1-Решение)
#
#     3.2 [*Вывод*](#3.2-Вывод)
#
#
# 4. [**Задание**](#Задание-№4)
#
#     4.1 [*Решение*](#4.1-Решение)
#
#     4.2 [*Вывод*](#4.2-Вывод)
#
#
# <br><br>
#
# # [**README проекта-->**](https://github.com/IvanoVladimir/karpov_courses/blob/main/SQL_project/README.md 'Ссылка на описание проекта')
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## [**Описание исследуемого набора данных**](#Marketing-metrics)
# ---
#
# <div class="alert alert-block alert-info">
# <ul><br>
#
# Структура и связи между таблицами:
#
# <img src=https://storage.yandexcloud.net/klms-public/production/learning-content/152/1762/17923/51794/244290/2023_01_24_214337_negate.jpg width="720" />
#
# </ul></br>
# </div>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <ul><br>
#
# **`users`** — информация о пользователях.
#
# Столбец	   |Тип данных  |Описание
# :-         |:-:         |:-
# user_id    |INT         |id пользователя
# birth_date |DATE        |дата рождения
# sex 	   |VARCHAR(50) |пол
#
#
# **`user_actions`** — действия пользователей с заказами.
#
# Столбец	 |Тип данных  |Описание
# :-       |:-:         |:-
# user_id	 |INT	      |id пользователя
# order_id |INT         |id заказа
# action	 |VARCHAR(50) |действие пользователя с заказом; 'create_order' — создание заказа, 'cancel_order' — отмена заказа
# time	 |TIMESTAMP   |время совершения действия
#
#
#  **`orders`** — информация о заказах.
#
# Столбец	      |Тип данных |Описание
# :-            |:-:        |:-
# order_id      |INT        |id заказа
# creation_time |TIMESTAMP  |время совершения действия
# product_ids	  |integer[]  |список id товаров в заказе
#
#
# **`products`** — информация о товарах, которые доставляет сервис.
#
# Столбец	   |Тип данных  |Описание
# :-         |:-:         |:-
# product_id |INT         |id продукта
# name 	   |VARCHAR(50) |название продукта
# price 	   |FLOAT(4)    |цена товара
#
#
# **`courier_actions`** — действия курьеров с заказами.
#
# Столбец	   |Тип данных	|Описание
# :-         |:-:         |:-
# courier_id |INT	        |id курьера
# order_id   |INT         |id заказа
# action	   |VARCHAR(50) |действие курьера с заказом; 'accept_order' — принятие заказа, 'deliver_order' — доставка заказа
# time	   |TIMESTAMP   |время совершения действия
#
#
# **`couriers`** — информация о курьерах.
#
# Столбец	   |Тип данных  |Описание
# :-         |:-:         |:-
# courier_id |INT         |id курьера
# birth_date |DATE        |дата рождения
# sex 	   |VARCHAR(50) |пол
#
# </ul></br>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <ul><br>
#
# **В рекламной кампании № 1** о нашем приложении рассказал известный блогер на Youtube-канале о кулинарии. На эту интеграцию суммарно потратили **250 тысяч рублей**. В результате этой кампании **1 сентября** в приложении зарегистрировался **171 человек**.
#
# **В рамках рекламной кампании №2** пользователям показывали таргетированную рекламу в социальных сетях. На это тоже суммарно потратили **250 тысяч рублей**, и в результе **1 сентября** у нас появилось **236 новых пользователей**.
#
# <br>
#
# Список id пользователей, пришедших после **рекламной кампании № 1**:
#
# 8631, 8632, 8638, 8643, 8657, 8673, 8706, 8707, 8715, 8723, 8732, 8739, 8741,
# 8750, 8751, 8752, 8770, 8774, 8788, 8791, 8804, 8810, 8815, 8828, 8830, 8845,
# 8853, 8859, 8867, 8869, 8876, 8879, 8883, 8896, 8909, 8911, 8933, 8940, 8972,
# 8976, 8988, 8990, 9002, 9004, 9009, 9019, 9020, 9035, 9036, 9061, 9069, 9071,
# 9075, 9081, 9085, 9089, 9108, 9113, 9144, 9145, 9146, 9162, 9165, 9167, 9175,
# 9180, 9182, 9197, 9198, 9210, 9223, 9251, 9257, 9278, 9287, 9291, 9313, 9317,
# 9321, 9334, 9351, 9391, 9398, 9414, 9420, 9422, 9431, 9450, 9451, 9454, 9472,
# 9476, 9478, 9491, 9494, 9505, 9512, 9518, 9524, 9526, 9528, 9531, 9535, 9550,
# 9559, 9561, 9562, 9599, 9603, 9605, 9611, 9612, 9615, 9625, 9633, 9652, 9654,
# 9655, 9660, 9662, 9667, 9677, 9679, 9689, 9695, 9720, 9726, 9739, 9740, 9762,
# 9778, 9786, 9794, 9804, 9810, 9813, 9818, 9828, 9831, 9836, 9838, 9845, 9871,
# 9887, 9891, 9896, 9897, 9916, 9945, 9960, 9963, 9965, 9968, 9971, 9993, 9998,
# 9999, 10001, 10013, 10016, 10023, 10030, 10051, 10057, 10064, 10082, 10103,
# 10105, 10122, 10134, 10135
#
#
# Список id пользователей, пришедших после **рекламной кампании № 2**:
#
# 8629, 8630, 8644, 8646, 8650, 8655, 8659, 8660, 8663, 8665, 8670, 8675, 8680, 8681,
# 8682, 8683, 8694, 8697, 8700, 8704, 8712, 8713, 8719, 8729, 8733, 8742, 8748, 8754,
# 8771, 8794, 8795, 8798, 8803, 8805, 8806, 8812, 8814, 8825, 8827, 8838, 8849, 8851,
# 8854, 8855, 8870, 8878, 8882, 8886, 8890, 8893, 8900, 8902, 8913, 8916, 8923, 8929,
# 8935, 8942, 8943, 8949, 8953, 8955, 8966, 8968, 8971, 8973, 8980, 8995, 8999, 9000,
# 9007, 9013, 9041, 9042, 9047, 9064, 9068, 9077, 9082, 9083, 9095, 9103, 9109, 9117,
# 9123, 9127, 9131, 9137, 9140, 9149, 9161, 9179, 9181, 9183, 9185, 9190, 9196, 9203,
# 9207, 9226, 9227, 9229, 9230, 9231, 9250, 9255, 9259, 9267, 9273, 9281, 9282, 9289,
# 9292, 9303, 9310, 9312, 9315, 9327, 9333, 9335, 9337, 9343, 9356, 9368, 9370, 9383,
# 9392, 9404, 9410, 9421, 9428, 9432, 9437, 9468, 9479, 9483, 9485, 9492, 9495, 9497,
# 9498, 9500, 9510, 9527, 9529, 9530, 9538, 9539, 9545, 9557, 9558, 9560, 9564, 9567,
# 9570, 9591, 9596, 9598, 9616, 9631, 9634, 9635, 9636, 9658, 9666, 9672, 9684, 9692,
# 9700, 9704, 9706, 9711, 9719, 9727, 9735, 9741, 9744, 9749, 9752, 9753, 9755, 9757,
# 9764, 9783, 9784, 9788, 9790, 9808, 9820, 9839, 9841, 9843, 9853, 9855, 9859, 9863,
# 9877, 9879, 9880, 9882, 9883, 9885, 9901, 9904, 9908, 9910, 9912, 9920, 9929, 9930,
# 9935, 9939, 9958, 9959, 9961, 9983, 10027, 10033, 10038, 10045, 10047, 10048, 10058,
# 10059, 10067, 10069, 10073, 10075, 10078, 10079, 10081, 10092, 10106, 10110, 10113, 10131
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## Задачи:
# ---
#
#  <div class="alert alert-block alert-info">
# <ul><br>
#
# ***Проанализировать метрики эффективности маркетинга для приложения по доставке продуктов недавно прошедших рекламных компаний:***
#
# 1. **ROI (Return on Investment)** - отражает рентабельность инвестиций и показывает  насколько выгодным является тот или иной проект или продукт. Какой вывод об эффективности рекламных кампаний можно сделать? В какой канал привлечения имеет смысл вкладывать больше бюджета?
#
# 2. **Average check** - средняя стоимость заказа привлечённых пользователей. Посчитать показатьель за первую неделю использования приложения с 1 по 7 сентября. Что можно сказать о среднем чеке пользователей в двух группах? Можно ли сказать  что в одной из групп он значительно выше  чем во второй?
#
# 3. **Retention rate** — коэффициент удержания клиентов. Почему же две рекламные кампании отличаются по значению метрики ROI? Какой вывод можно сделать?
#
# 4. **Накопительный ARPPU (Average Revenue Per Paying User)** — средняя выручка на одного платящего пользователя за определённый период и CAC **(Customer Acquisition Cost)** - отражает затраты на привлечение одного покупателя. Сравним эти две метрики  чтобы определить затраты и окупаемость каждой компании.
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## [**`Задание №1`**](#Marketing-metrics)
# ---
#
#  <div class="alert alert-block alert-info">
# <ul><br>
#
# Рассчитайте **ROI** для каждого рекламного канала.
#
# Колонку с наименованиями кампаний назовите *`ads_campaign`*  а колонку со значением метрики — *`roi`*.
#
# Наименования кампаний выведите в следующем виде:
#
# `Кампания № 1`<br>
# `Кампания № 2`
#
#
# Полученные значения метрики необходимо выразить в процентах и округлить **до двух знаков после запятой**.
#
# Результат должен быть отсортирован по убыванию значения метрики.
#
# Поля в результирующей таблице: *`ads_campaign`*  *`roi`*
#
# **Пояснение**:
#
# Покупателями будем считать тех пользователей, которые сделали хотя бы один заказ, который в дальнейшем не был отменён. Например, если человек сделал только один заказ, а потом отменил его, то покупателем мы его не считаем.
#
# Не забывайте при делении заранее приводить значения к нужному типу данных.
#
# Списки зарегистрировавшихся пользователей те же, что и на предыдущем шаге.
#
# <br>
# После того как составите запрос, попробуйте визуализировать результаты анализа.
#
# <br><br>
# Какой вывод об эффективности рекламных кампаний можно сделать? В какой канал привлечения имеет смысл вкладывать больше бюджета?
#
# </br></br></br></br></br></br></br></br>
#
# </ul></br>
# </div>

# %% [markdown]
# -----
# ###  [**`1.1 Решение`**](#Marketing-metrics)
# -----

# %%
from IPython.display import IFrame

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ul><br>
#
# <b>SELECT</b><br>
# ads_campaign,<br>
# <b>ROUND</b>((<b>SUM</b>(price) - 250000)::<b>DECIMAL</b> / 250000 * 100, 2) <b>AS</b> roi<br>
# <b>FROM</b>(<br>
# (<br>
# <b>SELECT</b><br>
# user_id,<br>
# order_id,<br>
# <b>CASE</b><br>
# <b>WHEN</b> user_id <b>IN</b>(<br>
# 8631, 8632, 8638, 8643, 8657, 8673, 8706, 8707, 8715, 8723, 8732, 8739, 8741,
# 8750, 8751, 8752, 8770, 8774, 8788, 8791, 8804, 8810, 8815, 8828, 8830, 8845,
# 8853, 8859, 8867, 8869, 8876, 8879, 8883, 8896, 8909, 8911, 8933, 8940, 8972,
# 8976, 8988, 8990, 9002, 9004, 9009, 9019, 9020, 9035, 9036, 9061, 9069, 9071,
# 9075, 9081, 9085, 9089, 9108, 9113, 9144, 9145, 9146, 9162, 9165, 9167, 9175,
# 9180, 9182, 9197, 9198, 9210, 9223, 9251, 9257, 9278, 9287, 9291, 9313, 9317,
# 9321, 9334, 9351, 9391, 9398, 9414, 9420, 9422, 9431, 9450, 9451, 9454, 9472,
# 9476, 9478, 9491, 9494, 9505, 9512, 9518, 9524, 9526, 9528, 9531, 9535, 9550,
# 9559, 9561, 9562, 9599, 9603, 9605, 9611, 9612, 9615, 9625, 9633, 9652, 9654,
# 9655, 9660, 9662, 9667, 9677, 9679, 9689, 9695, 9720, 9726, 9739, 9740, 9762,
# 9778, 9786, 9794, 9804, 9810, 9813, 9818, 9828, 9831, 9836, 9838, 9845, 9871,
# 9887, 9891, 9896, 9897, 9916, 9945, 9960, 9963, 9965, 9968, 9971, 9993, 9998,
# 9999, 10001, 10013, 10016, 10023, 10030, 10051, 10057, 10064, 10082, 10103,
# 10105, 10122, 10134, 10135)<br>
# <b>THEN</b> 'Кампания № 1'<br>
# <b>WHEN</b> user_id <b>IN</b>(<br>
# 8629, 8630, 8644, 8646, 8650, 8655, 8659, 8660, 8663, 8665, 8670, 8675, 8680, 8681,
# 8682, 8683, 8694, 8697, 8700, 8704, 8712, 8713, 8719, 8729, 8733, 8742, 8748, 8754,
# 8771, 8794, 8795, 8798, 8803, 8805, 8806, 8812, 8814, 8825, 8827, 8838, 8849, 8851,
# 8854, 8855, 8870, 8878, 8882, 8886, 8890, 8893, 8900, 8902, 8913, 8916, 8923, 8929,
# 8935, 8942, 8943, 8949, 8953, 8955, 8966, 8968, 8971, 8973, 8980, 8995, 8999, 9000,
# 9007, 9013, 9041, 9042, 9047, 9064, 9068, 9077, 9082, 9083, 9095, 9103, 9109, 9117,
# 9123, 9127, 9131, 9137, 9140, 9149, 9161, 9179, 9181, 9183, 9185, 9190, 9196, 9203,
# 9207, 9226, 9227, 9229, 9230, 9231, 9250, 9255, 9259, 9267, 9273, 9281, 9282, 9289,
# 9292, 9303, 9310, 9312, 9315, 9327, 9333, 9335, 9337, 9343, 9356, 9368, 9370, 9383,
# 9392, 9404, 9410, 9421, 9428, 9432, 9437, 9468, 9479, 9483, 9485, 9492, 9495, 9497,
# 9498, 9500, 9510, 9527, 9529, 9530, 9538, 9539, 9545, 9557, 9558, 9560, 9564, 9567,
# 9570, 9591, 9596, 9598, 9616, 9631, 9634, 9635, 9636, 9658, 9666, 9672, 9684, 9692,
# 9700, 9704, 9706, 9711, 9719, 9727, 9735, 9741, 9744, 9749, 9752, 9753, 9755, 9757,
# 9764, 9783, 9784, 9788, 9790, 9808, 9820, 9839, 9841, 9843, 9853, 9855, 9859, 9863,
# 9877, 9879, 9880, 9882, 9883, 9885, 9901, 9904, 9908, 9910, 9912, 9920, 9929, 9930,
# 9935, 9939, 9958, 9959, 9961, 9983, 10027, 10033, 10038, 10045, 10047, 10048, 10058,
# 10059, 10067, 10069, 10073, 10075, 10078, 10079, 10081, 10092, 10106, 10110, 10113, 10131)<br>
# <b>THEN</b> 'Кампания № 2'<br>
# <b>END</b> ads_campaign<br>
# <b>FROM</b> user_actions<br>
# <b>WHERE</b> order_id <b>NOT IN</b>(<br>
# <b>SELECT</b><br>
# order_id<br>
# <b>FROM</b> user_actions<br>
# <b>WHERE</b> action ='cancel_order')) <b>AS</b> LT2<br>
# <b>LEFT JOIN</b>(<br>
# (<br>
# <b>SELECT</b><br>
# order_id,<br>
# <b>UNNEST</b>(product_ids) <b>AS</b> product_id<br>
# <b>FROM</b> orders) <b>AS</b> LT1<br>
# <b>JOIN</b> products <br>
# <b>USING</b>(product_id)<br>
# ) <b>AS</b> RT2<br>
# <b>USING</b>(order_id)<br>
# ) <b>AS</b> T<br>
# <b>WHERE</b> ads_campaign <b>IS NOT NULL</b><br>
# <b>GROUP BY</b> ads_campaign<br>
# <b>ORDER BY</b> roi <b>DESC</b><br>
#
# </ul></br>
# </div>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/39683/visualization/61251?api_key=iXJBgW6b8UCMQLO8eWEWOj1qXiK9DubAtud3eDL3&', 480, 240)
# Out:
#         <iframe
#             width="480"
#             height="240"
#             src="http://redash.public.karpov.courses/embed/query/39683/visualization/61251?api_key=iXJBgW6b8UCMQLO8eWEWOj1qXiK9DubAtud3eDL3&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/39683/visualization/61254?api_key=iXJBgW6b8UCMQLO8eWEWOj1qXiK9DubAtud3eDL3&', 640, 640)
# Out:
#         <iframe
#             width="640"
#             height="640"
#             src="http://redash.public.karpov.courses/embed/query/39683/visualization/61254?api_key=iXJBgW6b8UCMQLO8eWEWOj1qXiK9DubAtud3eDL3&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# -----
# ###  [**`1.2 Вывод`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <ul><br>
#
# Первая кампания имеет **положительный ROI**, то есть позволяет окупать рекламные затраты. В то же время у второй рекламной кампании **ROI отрицательный** — пока что она работает в минус. Возможно со временем эти показатели изменятся, но на текущий момент первая рекламная кампания — более выгодное направление для инвестиций рекламного бюджета.
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## [**`Задание №2`**](#Marketing-metrics)
# ---
#
#  <div class="alert alert-block alert-info">
# <ul><br>
#
# Для каждой рекламной кампании посчитайте среднюю стоимость заказа привлечённых пользователей за первую неделю использования приложения **с 1 по 7 сентября 2022 года**.
#
# Колонку с наименованиями кампаний назовите *`ads_campaign`*, а колонку со значением метрики — *`avg_check`*.
#
# Наименования кампаний выведите в следующем виде:
#
# `Кампания № 1`<br>
# `Кампания № 2`
#
#
# Полученные значения метрики необходимо округлить **до двух знаков после запятой**.
#
# Результат должен быть отсортирован по убыванию значения метрики.
#
# Поля в результирующей таблице: *`ads_campaign`*  *`avg_check`*
#
# **Пояснение**:
#
# Покупателями будем считать тех пользователей, которые сделали хотя бы один заказ, который в дальнейшем не был отменён. Например, если человек сделал только один заказ,а потом отменил его, то покупателем мы его не считаем.
#
# Не забывайте при делении заранее приводить значения к нужному типу данных.
#
# Списки зарегистрировавшихся пользователей те же, что и на предыдущем шаге.
#
# <br>
# После того как составите запрос, попробуйте визуализировать результаты анализа.
#
# <br><br>
# Что можно сказать о среднем чеке пользователей в двух группах? Можно ли сказать, что в одной из групп он значительно выше, чем во второй?
#
# </br></br></br></br></br></br></br></br>
#
# </ul></br>
# </div>

# %% [markdown]
# -----
# ###  [**`2.1 Решение`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ul><br>
#
# <b>SELECT</b><br>
# ads_campaign,<br>
# <b>ROUND</b>((<b>AVG</b>(avg_check)), 2) <b>AS</b> avg_check<br>
# <b>FROM</b><br>
# (<b>SELECT</b><br>
# user_id,<br>
# ads_campaign,<br>
# <b>AVG</b>(summary) <b>AS</b> avg_check<br>
# <b>FROM</b><br>
# (<br>
# <b>SELECT</b> user_id,<br>
# <b>CASE</b><br>
# <b>WHEN</b> user_id <b>IN</b>(<br>
# 8631, 8632, 8638, 8643, 8657, 8673, 8706, 8707, 8715, 8723, 8732, 8739, 8741,
# 8750, 8751, 8752, 8770, 8774, 8788, 8791, 8804, 8810, 8815, 8828, 8830, 8845,
# 8853, 8859, 8867, 8869, 8876, 8879, 8883, 8896, 8909, 8911, 8933, 8940, 8972,
# 8976, 8988, 8990, 9002, 9004, 9009, 9019, 9020, 9035, 9036, 9061, 9069, 9071,
# 9075, 9081, 9085, 9089, 9108, 9113, 9144, 9145, 9146, 9162, 9165, 9167, 9175,
# 9180, 9182, 9197, 9198, 9210, 9223, 9251, 9257, 9278, 9287, 9291, 9313, 9317,
# 9321, 9334, 9351, 9391, 9398, 9414, 9420, 9422, 9431, 9450, 9451, 9454, 9472,
# 9476, 9478, 9491, 9494, 9505, 9512, 9518, 9524, 9526, 9528, 9531, 9535, 9550,
# 9559, 9561, 9562, 9599, 9603, 9605, 9611, 9612, 9615, 9625, 9633, 9652, 9654,
# 9655, 9660, 9662, 9667, 9677, 9679, 9689, 9695, 9720, 9726, 9739, 9740, 9762,
# 9778, 9786, 9794, 9804, 9810, 9813, 9818, 9828, 9831, 9836, 9838, 9845, 9871,
# 9887, 9891, 9896, 9897, 9916, 9945, 9960, 9963, 9965, 9968, 9971, 9993, 9998,
# 9999, 10001, 10013, 10016, 10023, 10030, 10051, 10057, 10064, 10082, 10103,
# 10105, 10122, 10134, 10135)<br>
# <b>THEN</b> 'Кампания № 1'<br>
# <b>WHEN</b> user_id <b>IN</b>(<br>
# 8629, 8630, 8644, 8646, 8650, 8655, 8659, 8660, 8663, 8665, 8670, 8675, 8680, 8681,
# 8682, 8683, 8694, 8697, 8700, 8704, 8712, 8713, 8719, 8729, 8733, 8742, 8748, 8754,
# 8771, 8794, 8795, 8798, 8803, 8805, 8806, 8812, 8814, 8825, 8827, 8838, 8849, 8851,
# 8854, 8855, 8870, 8878, 8882, 8886, 8890, 8893, 8900, 8902, 8913, 8916, 8923, 8929,
# 8935, 8942, 8943, 8949, 8953, 8955, 8966, 8968, 8971, 8973, 8980, 8995, 8999, 9000,
# 9007, 9013, 9041, 9042, 9047, 9064, 9068, 9077, 9082, 9083, 9095, 9103, 9109, 9117,
# 9123, 9127, 9131, 9137, 9140, 9149, 9161, 9179, 9181, 9183, 9185, 9190, 9196, 9203,
# 9207, 9226, 9227, 9229, 9230, 9231, 9250, 9255, 9259, 9267, 9273, 9281, 9282, 9289,
# 9292, 9303, 9310, 9312, 9315, 9327, 9333, 9335, 9337, 9343, 9356, 9368, 9370, 9383,
# 9392, 9404, 9410, 9421, 9428, 9432, 9437, 9468, 9479, 9483, 9485, 9492, 9495, 9497,
# 9498, 9500, 9510, 9527, 9529, 9530, 9538, 9539, 9545, 9557, 9558, 9560, 9564, 9567,
# 9570, 9591, 9596, 9598, 9616, 9631, 9634, 9635, 9636, 9658, 9666, 9672, 9684, 9692,
# 9700, 9704, 9706, 9711, 9719, 9727, 9735, 9741, 9744, 9749, 9752, 9753, 9755, 9757,
# 9764, 9783, 9784, 9788, 9790, 9808, 9820, 9839, 9841, 9843, 9853, 9855, 9859, 9863,
# 9877, 9879, 9880, 9882, 9883, 9885, 9901, 9904, 9908, 9910, 9912, 9920, 9929, 9930,
# 9935, 9939, 9958, 9959, 9961, 9983, 10027, 10033, 10038, 10045, 10047, 10048, 10058,
# 10059, 10067, 10069, 10073, 10075, 10078, 10079, 10081, 10092, 10106, 10110, 10113, 10131)<br>
# <b>THEN</b> 'Кампания № 2'<br>
# <b>END</b> ads_campaign,<br>
# order_id,<br>
# <b>SUM</b>(price) <b>AS</b> summary<br>
# <b>FROM</b> user_actions<br>
# <b>JOIN</b><br>
# ((<br>
# <b>SELECT</b><br>
# order_id,<br>
# <b>UNNEST(product_ids) <b>AS</b> product_id<br>
# <b>FROM</b> orders<br>
# ) <b>AS LT1<br>
# <b>JOIN</b> products<br>
# <b>USING</b>(product_id)<br>
# ) <b>AS</b> RT1<br>
# <b>USING</b>(order_id)<br>
# <b>WHERE</b> order_id <b>NOT IN</b>(<br>
# <b>SELECT</b><br>
# order_id<br>
# <b>FROM</b> user_actions</b><br>
# <b>WHERE</b> action ='cancel_order')<br>
# <b>AND</b> time::<b>DATE</b> <b>BETWEEN</b> '2022-09-01' <b>AND</b> '2022-09-07'<br>
# <b>GROUP BY</b> user_id, order_id<br>
# ) <b>AS</b> T1<br>
# <b>WHERE</b> ads_campaign IS NOT NULL</b><br>
# <b>GROUP BY</b> user_id, ads_campaign<br>
# ) <b>AS</b> T2<br>
# <b>GROUP BY</b> ads_campaign<br>
# <b>ORDER BY</b> avg_check <b>DESC</b><br>
#
# </ul></br>
# </div>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/39686/visualization/61255?api_key=MQJ8vu2NyASsDTP13t6oJBNJai36iRymHWc749XI&', 640, 240)
# Out:
#         <iframe
#             width="640"
#             height="240"
#             src="http://redash.public.karpov.courses/embed/query/39686/visualization/61255?api_key=MQJ8vu2NyASsDTP13t6oJBNJai36iRymHWc749XI&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/39686/visualization/61259?api_key=MQJ8vu2NyASsDTP13t6oJBNJai36iRymHWc749XI&', 640, 640)
# Out:
#         <iframe
#             width="640"
#             height="640"
#             src="http://redash.public.karpov.courses/embed/query/39686/visualization/61259?api_key=MQJ8vu2NyASsDTP13t6oJBNJai36iRymHWc749XI&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# -----
# ###  [**`2.2 Вывод`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <ul><br>
#
# Конечно, сказать однозначно, отличаются ли группы по среднему чеку, без статистических тестов нельзя, но всё же можно предположить, что различия несущественные. И что особенно интересно - средней чек даже немного выше во второй группе <b>с отрицательным ROI</b>.
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## [**`Задание №3`**](#Marketing-metrics)
# ---
#
# <div class="alert alert-block alert-info">
# <ul><br>
#
# Для каждой рекламной кампании посчитайте <b>Retention</b> 1-го и 7-го дня у привлечённых пользователей.
#
# В результат включите четыре колонки: колонку с наименованиями кампаний, дату первого взаимодействия с приложением, количество дней, прошедших с даты первого взаимодействия (порядковый номер), и само значение <b>Retention.</b>
#
# Колонки со значениями назовите соответственно *`ads_campaign`*, *`start_date`*, *`day_number`*, *`retention`*.
#
# Наименования кампаний выведите в следующем виде:
#
# `Кампания № 1`<br>
# `Кампания № 2`
#
# Метрику необходимо выразить в виде доли, округлив полученные значения **до двух знаков после запятой**.
#
# Результат должен быть отсортирован сначала по наименованию кампании (по возрастанию), затем по возрастанию порядкового номера дня.
#
# В результат должны попасть следующие дни: **нулевой, первый и седьмой**.
#
# Поля в результирующей таблице:  *`ads_campaign`*, *`start_date`*, *`day_number`*, *`retention`*
#
# **Пояснение**:
#
# Не забывайте при делении заранее приводить значения к нужному типу данных.
#
# Списки зарегистрировавшихся пользователей те же, что и на предыдущих шагах.
#
# <br>
#
# После того как составите запрос, попробуйте визуализировать результаты анализа с помощью сводной таблицы.
#
# Так почему же две рекламные кампании отличаются по значению метрики **ROI**? Какой теперь вывод можно сделать?
#
# </br></br></br></br></br></br></br></br>
#
# </ul></br>
# </div>

# %% [markdown]
# -----
# ###  [**`3.1 Решение`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ul><br>
#
# **WITH** CTE1 **AS**(<br>
# **SELECT**<br>
# user_id,<br>
# time::**DATE** **AS** action_date,<br>
# **MIN**(time::**DATE**) **OVER**(**PARTITION BY** user_id) **AS** start_date,<br>
# **CASE**<br>
# **WHEN** user_id **IN**(<br>
# 8631, 8632, 8638, 8643, 8657, 8673, 8706, 8707, 8715, 8723, 8732, 8739, 8741,
# 8750, 8751, 8752, 8770, 8774, 8788, 8791, 8804, 8810, 8815, 8828, 8830, 8845,
# 8853, 8859, 8867, 8869, 8876, 8879, 8883, 8896, 8909, 8911, 8933, 8940, 8972,
# 8976, 8988, 8990, 9002, 9004, 9009, 9019, 9020, 9035, 9036, 9061, 9069, 9071,
# 9075, 9081, 9085, 9089, 9108, 9113, 9144, 9145, 9146, 9162, 9165, 9167, 9175,
# 9180, 9182, 9197, 9198, 9210, 9223, 9251, 9257, 9278, 9287, 9291, 9313, 9317,
# 9321, 9334, 9351, 9391, 9398, 9414, 9420, 9422, 9431, 9450, 9451, 9454, 9472,
# 9476, 9478, 9491, 9494, 9505, 9512, 9518, 9524, 9526, 9528, 9531, 9535, 9550,
# 9559, 9561, 9562, 9599, 9603, 9605, 9611, 9612, 9615, 9625, 9633, 9652, 9654,
# 9655, 9660, 9662, 9667, 9677, 9679, 9689, 9695, 9720, 9726, 9739, 9740, 9762,
# 9778, 9786, 9794, 9804, 9810, 9813, 9818, 9828, 9831, 9836, 9838, 9845, 9871,
# 9887, 9891, 9896, 9897, 9916, 9945, 9960, 9963, 9965, 9968, 9971, 9993, 9998,
# 9999, 10001, 10013, 10016, 10023, 10030, 10051, 10057, 10064, 10082, 10103,
# 10105, 10122, 10134, 10135)<br>
# **THEN** 'Кампания № 1'<br>
# **WHEN** user_id **IN**(<br>
# 8629, 8630, 8644, 8646, 8650, 8655, 8659, 8660, 8663, 8665, 8670, 8675, 8680, 8681,
# 8682, 8683, 8694, 8697, 8700, 8704, 8712, 8713, 8719, 8729, 8733, 8742, 8748, 8754,
# 8771, 8794, 8795, 8798, 8803, 8805, 8806, 8812, 8814, 8825, 8827, 8838, 8849, 8851,
# 8854, 8855, 8870, 8878, 8882, 8886, 8890, 8893, 8900, 8902, 8913, 8916, 8923, 8929,
# 8935, 8942, 8943, 8949, 8953, 8955, 8966, 8968, 8971, 8973, 8980, 8995, 8999, 9000,
# 9007, 9013, 9041, 9042, 9047, 9064, 9068, 9077, 9082, 9083, 9095, 9103, 9109, 9117,
# 9123, 9127, 9131, 9137, 9140, 9149, 9161, 9179, 9181, 9183, 9185, 9190, 9196, 9203,
# 9207, 9226, 9227, 9229, 9230, 9231, 9250, 9255, 9259, 9267, 9273, 9281, 9282, 9289,
# 9292, 9303, 9310, 9312, 9315, 9327, 9333, 9335, 9337, 9343, 9356, 9368, 9370, 9383,
# 9392, 9404, 9410, 9421, 9428, 9432, 9437, 9468, 9479, 9483, 9485, 9492, 9495, 9497,
# 9498, 9500, 9510, 9527, 9529, 9530, 9538, 9539, 9545, 9557, 9558, 9560, 9564, 9567,
# 9570, 9591, 9596, 9598, 9616, 9631, 9634, 9635, 9636, 9658, 9666, 9672, 9684, 9692,
# 9700, 9704, 9706, 9711, 9719, 9727, 9735, 9741, 9744, 9749, 9752, 9753, 9755, 9757,
# 9764, 9783, 9784, 9788, 9790, 9808, 9820, 9839, 9841, 9843, 9853, 9855, 9859, 9863,
# 9877, 9879, 9880, 9882, 9883, 9885, 9901, 9904, 9908, 9910, 9912, 9920, 9929, 9930,
# 9935, 9939, 9958, 9959, 9961, 9983, 10027, 10033, 10038, 10045, 10047, 10048, 10058,
# 10059, 10067, 10069, 10073, 10075, 10078, 10079, 10081, 10092, 10106, 10110, 10113, 10131)<br>
# **THEN** 'Кампания № 2'<br>
# **END** ads_campaign<br>
# **FROM**<br>
# user_actions),<br>
# CTE2 **AS**(<br>
# **SELECT**<br>
# start_date,<br>
# action_date,<br>
# ads_campaign,<br>
# **COUNT**(**DISTINCT** user_id) **AS** uniq_users<br>
# **FROM** CTE1<br>
# **WHERE** ads_campaign **IS NOT NULL**<br>
# **GROUP BY** 1, 2, 3)<br>
# <br>
# **SELECT**<br>
# ads_campaign,<br>
# start_date,<br>
# action_date - start_date  **AS** day_number,<br>
# **ROUND**(uniq_users::**DECIMAL** / **MAX**(uniq_users) **OVER**(**PARTITION BY** start_date, ads_campaign), 2) **AS** retention<br>
# **FROM** CTE2<br>
# **WHERE** action_date - start_date **IN**(0, 1, 7)<br>
# **ORDER BY** ads_campaign, day_number<br>
#
# </ul></br>
# </div>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/40039/visualization/61826?api_key=xGcYEtZLeXuRmBa7xhWJguOmlwaWtxtwsZayCpiW&', 480, 320)
# Out:
#         <iframe
#             width="480"
#             height="320"
#             src="http://redash.public.karpov.courses/embed/query/40039/visualization/61826?api_key=xGcYEtZLeXuRmBa7xhWJguOmlwaWtxtwsZayCpiW&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# -----
# ###  [**`3.2 Вывод`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <ul><br>
#
# Пользователи из обоих рекламных каналов практически не различаются по среднему чеку, но Retention почти в два раза выше у первой группы. Это и приводит к тому, что пользователи из первой группы приносят нам больше денег.
#
# </ul></br>
# </div>

# %% [markdown]
# ---
# ## [**`Задание №4`**](#Marketing-metrics)
# ---
#
# <div class="alert alert-block alert-info">
# <ul><br>
#
# Для каждой рекламной кампании для каждого дня посчитайте две метрики:
#
# 1. Накопительный ARPPU.
#
# 2. Затраты на привлечение одного покупателя (CAC).
#
# Колонку с наименованиями кампаний назовите *`ads_campaign`*, колонку с днями — *`day`*, а колонки со значениями метрик — *`cumulative_arppu`* и *`cac`*.
#
# Значения метрики **CAC** укажите одинаковым для всех дней (это необходимо для наглядной визуализации).
#
# Наименования кампаний выведите в следующем виде:
#
# Кампания № 1
#
# `Кампания № 1`<br>
# `Кампания № 2`
#
# Дни пронумеруйте начиная с 0 и отобразите в следующем формате:
#
# `Day 0`<br>
# `Day 1`<br>
# `Day 2`<br>
# `и т.д.`
#
# Полученные значения метрики необходимо выразить в процентах и округлить **до двух знаков после запятой**.
#
# Результат должен быть отсортирован сначала по наименованию кампании (по возрастанию), затем по наименованию дня (также по возрастанию).
#
# Поля в результирующей таблице: *`ads_campaign`*, *`day`*, *`cumulative_arppu`*, *`cac`*
#
# **Пояснение**:
#
# Покупателями будем считать тех пользователей, которые сделали хотя бы один заказ, который в дальнейшем не был отменён. Например, если человек сделал только один заказ, а потом отменил его, то покупателем мы его не считаем.
#
# Не забывайте при делении заранее приводить значения к нужному типу данных.
#
# Списки зарегистрировавшихся пользователей те же, что и на предыдущем шаге.
#
# <br>
# После того как составите запрос, попробуйте визуализировать результаты анализа.
#
# <br>
#
# Какой вывод можно сделать на основе построенных графиков?
#
# </ul></br>
# </div>

# %% [markdown]
# -----
# ###  [**`4.1 Решение`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ul><br>
#
# **WITH** CTE1 **AS**(<br>
# **SELECT**<br>
# user_id,<br>
# order_id,<br>
# time::**DATE** - **MIN**(time::**DATE**) **OVER**(**PARTITION BY** user_id) **AS** day,<br>
# **CASE**<br>
# **WHEN** user_id **IN**(<br>
# 8631, 8632, 8638, 8643, 8657, 8673, 8706, 8707, 8715, 8723, 8732, 8739, 8741,
# 8750, 8751, 8752, 8770, 8774, 8788, 8791, 8804, 8810, 8815, 8828, 8830, 8845,
# 8853, 8859, 8867, 8869, 8876, 8879, 8883, 8896, 8909, 8911, 8933, 8940, 8972,
# 8976, 8988, 8990, 9002, 9004, 9009, 9019, 9020, 9035, 9036, 9061, 9069, 9071,
# 9075, 9081, 9085, 9089, 9108, 9113, 9144, 9145, 9146, 9162, 9165, 9167, 9175,
# 9180, 9182, 9197, 9198, 9210, 9223, 9251, 9257, 9278, 9287, 9291, 9313, 9317,
# 9321, 9334, 9351, 9391, 9398, 9414, 9420, 9422, 9431, 9450, 9451, 9454, 9472,
# 9476, 9478, 9491, 9494, 9505, 9512, 9518, 9524, 9526, 9528, 9531, 9535, 9550,
# 9559, 9561, 9562, 9599, 9603, 9605, 9611, 9612, 9615, 9625, 9633, 9652, 9654,
# 9655, 9660, 9662, 9667, 9677, 9679, 9689, 9695, 9720, 9726, 9739, 9740, 9762,
# 9778, 9786, 9794, 9804, 9810, 9813, 9818, 9828, 9831, 9836, 9838, 9845, 9871,
# 9887, 9891, 9896, 9897, 9916, 9945, 9960, 9963, 9965, 9968, 9971, 9993, 9998,
# 9999, 10001, 10013, 10016, 10023, 10030, 10051, 10057, 10064, 10082, 10103,
# 10105, 10122, 10134, 10135)<br>
# **THEN** 'Кампания № 1'<br>
# **WHEN** user_id IN(<br>
# 8629, 8630, 8644, 8646, 8650, 8655, 8659, 8660, 8663, 8665, 8670, 8675, 8680, 8681,
# 8682, 8683, 8694, 8697, 8700, 8704, 8712, 8713, 8719, 8729, 8733, 8742, 8748, 8754,
# 8771, 8794, 8795, 8798, 8803, 8805, 8806, 8812, 8814, 8825, 8827, 8838, 8849, 8851,
# 8854, 8855, 8870, 8878, 8882, 8886, 8890, 8893, 8900, 8902, 8913, 8916, 8923, 8929,
# 8935, 8942, 8943, 8949, 8953, 8955, 8966, 8968, 8971, 8973, 8980, 8995, 8999, 9000,
# 9007, 9013, 9041, 9042, 9047, 9064, 9068, 9077, 9082, 9083, 9095, 9103, 9109, 9117,
# 9123, 9127, 9131, 9137, 9140, 9149, 9161, 9179, 9181, 9183, 9185, 9190, 9196, 9203,
# 9207, 9226, 9227, 9229, 9230, 9231, 9250, 9255, 9259, 9267, 9273, 9281, 9282, 9289,
# 9292, 9303, 9310, 9312, 9315, 9327, 9333, 9335, 9337, 9343, 9356, 9368, 9370, 9383,
# 9392, 9404, 9410, 9421, 9428, 9432, 9437, 9468, 9479, 9483, 9485, 9492, 9495, 9497,
# 9498, 9500, 9510, 9527, 9529, 9530, 9538, 9539, 9545, 9557, 9558, 9560, 9564, 9567,
# 9570, 9591, 9596, 9598, 9616, 9631, 9634, 9635, 9636, 9658, 9666, 9672, 9684, 9692,
# 9700, 9704, 9706, 9711, 9719, 9727, 9735, 9741, 9744, 9749, 9752, 9753, 9755, 9757,
# 9764, 9783, 9784, 9788, 9790, 9808, 9820, 9839, 9841, 9843, 9853, 9855, 9859, 9863,
# 9877, 9879, 9880, 9882, 9883, 9885, 9901, 9904, 9908, 9910, 9912, 9920, 9929, 9930,
# 9935, 9939, 9958, 9959, 9961, 9983, 10027, 10033, 10038, 10045, 10047, 10048, 10058,
# 10059, 10067, 10069, 10073, 10075, 10078, 10079, 10081, 10092, 10106, 10110, 10113, 10131)<br>
# **THEN** 'Кампания № 2'<br>
# **END** ads_campaign<br>
# **FROM** user_actions),<br>
# CTE2 **AS**(<br>
# **SELECT** **DISTINCT**<br>
# day,<br>
# ads_campaign,<br>
# **SUM**(order_value) **OVER**(**PARTITION BY** ads_campaign, day) **AS** revenue<br>
# **FROM** CTE1<br>
# **JOIN**(<br>
# **SELECT**<br>
# order_id,<br>
# **SUM**(price) **AS** order_value<br>
# **FROM**(<br>
# **SELECT**<br>
# order_id,<br>
# **UNNEST**(product_ids) **AS** product_id<br>
# **FROM** orders<br>
# **WHERE** order_id **NOT IN** (<br>
# **SELECT** order_id<br>
# **FROM** user_actions<br>
# **WHERE** action='cancel_order')<br>
# ) **AS** orders<br>
# **JOIN** products<br>
# **USING**(product_id)<br>
# **GROUP BY** order_id<br>
# ) **AS** prices <br>
# **USING**(order_id)),<br>
# CTE3 **AS**(<br>
# **SELECT**<br>
# ads_campaign,<br>
# **COUNT**(distinct user_id) **AS** paying_users,<br>
# **ROUND**(250000/ count(distinct user_id)::decimal,2) **AS** cac<br>
# **FROM** CTE1<br>
# **WHERE** order_id **NOT IN**(**SELECT** order_id **FROM** user_actions **WHERE** action = 'cancel_order')<br>
# **GROUP BY** ads_campaign),<br>
# CTE4 **AS**(<br>
# **SELECT DISTINCT**<br>
# ads_campaign **AS** ads_campaign1,<br>
# **CONCAT**('Day ', day) **AS** day,<br>
# **ROUND**(**SUM**(revenue) **OVER**(**PARTITION BY** ads_campaign **ORDER BY** day)/ **MAX**(paying_users) **OVER**(**PARTITION BY** ads_campaign)::**DECIMAl**,2) **AS** cumulative_arppu1,<br>
# cac **AS** cac1<br>
# **FROM** CTE2<br>
# **JOIN** CTE3<br>
# **USING**(ads_campaign)<br>
# **WHRERE** ads_campaign = 'Кампания № 1'),<br>
# CTE5 **AS**(<br>
# **SELECT DISTINCT**<br>
# ads_campaign **AS** ads_campaign2,<br>
# **CONCAT**('Day ', day) **AS** day,<br>
# **ROUND**(**SUM**(revenue) **OVER**(**PARTITION BY** ads_campaign **ORDER BY** day)/ **MAX**(paying_users) **OVER**(**PARTITION BY** ads_campaign)::**DECIMAL**,2) **AS** cumulative_arppu2,<br>
# cac **AS** cac2<br>
# **FROM** CTE2<br>
# **JOIN** CTE3<br>
# **USING**(ads_campaign)<br>
# **WHERE** ads_campaign = 'Кампания № 2')<br>
# <br>
# **SELECT** * **FROM** CTE4<br>
# **JOIN** CTE5<br>
# **USING**(day)<br>
# **ORDER BY** day<br>
#
# </ul></br>
# </div>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/40052/visualization/61905?api_key=vj2iPm6ebZnruSO26PEGZcOTpmw0D1dfln0mLq4M&', 840, 400)
# Out:
#         <iframe
#             width="840"
#             height="400"
#             src="http://redash.public.karpov.courses/embed/query/40052/visualization/61905?api_key=vj2iPm6ebZnruSO26PEGZcOTpmw0D1dfln0mLq4M&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame('http://redash.public.karpov.courses/embed/query/40052/visualization/61906?api_key=vj2iPm6ebZnruSO26PEGZcOTpmw0D1dfln0mLq4M&', 840, 400)
# Out:
#         <iframe
#             width="840"
#             height="400"
#             src="http://redash.public.karpov.courses/embed/query/40052/visualization/61906?api_key=vj2iPm6ebZnruSO26PEGZcOTpmw0D1dfln0mLq4M&"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# -----
# ###  [**`4.2 Вывод`**](#Marketing-metrics)
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <ul><br>
#
# Для первой рекламной кампании **накопительный ARPPU превысил затраты на привлечение одного покупателя (CAC) уже на 5-й день**, тогда как для второй кампании **даже на 7-й день значение CAC всё ещё превышало значение ARPPU**.
#
# </ul></br>
# </div>

# %%
IFrame('http://redash.public.karpov.courses/public/dashboards/6ARqRN93me6cgmHxweQEG32hHG5jOW85wwNTywFO?org_slug=default', 1660, 840)
# Out:
#         <iframe
#             width="1660"
#             height="840"
#             src="http://redash.public.karpov.courses/public/dashboards/6ARqRN93me6cgmHxweQEG32hHG5jOW85wwNTywFO?org_slug=default"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # [**К содержанию -->**](#Marketing-metrics)
# ---
